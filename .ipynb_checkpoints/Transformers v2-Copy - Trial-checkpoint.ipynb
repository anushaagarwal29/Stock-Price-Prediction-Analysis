# %%
import yfinance as yf
import pandas as pd
import numpy as np

# Download AAPL stock data from 2015 to 2019
aapl_data = yf.download('AAPL', start='2015-01-01', end='2019-12-30', interval='1d')

# Create additional features
aapl_data['width'] = aapl_data['High'] - aapl_data['Low']  # Daily range (High - Low)
aapl_data['diff'] = aapl_data['Close'].diff()  # Price difference
aapl_data['pct_change'] = aapl_data['Close'].pct_change()  # Percentage price change

# Relative Strength Index (RSI)
window_length = 14
delta = aapl_data['Close'].diff()
gain = (delta.where(delta > 0, 0)).rolling(window=window_length).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=window_length).mean()
rs = gain / loss
aapl_data['RSI'] = 100 - (100 / (1 + rs))

# Rate of Change (ROC)
aapl_data['ROC'] = aapl_data['Close'].pct_change(periods=window_length) * 100

# Drop NaN values created by rolling calculations
aapl_data.dropna(inplace=True)

# Display the first few rows to check the created features
aapl_data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2015-01-23  28.075001  28.437500  27.882500  28.245001  25.187689  185859200
# 2015-01-26  28.434999  28.590000  28.200001  28.275000  25.214445  222460000
# 2015-01-27  28.105000  28.120001  27.257500  27.285000  24.331600  382274800
# 2015-01-28  29.407499  29.530001  28.827499  28.827499  25.707136  585908400
# 2015-01-29  29.080000  29.797501  28.889999  29.725000  26.507488  337745600
#
#                width      diff  pct_change        RSI       ROC
# Date
# 2015-01-23  0.555000  0.145000    0.005160  57.671288  3.338518
# 2015-01-26  0.389999  0.029999    0.001062  66.442620  6.447057
# 2015-01-27  0.862501 -0.990000   -0.035013  55.811131  2.710331
# 2015-01-28  0.702501  1.542500    0.056533  62.830950  7.016239
# 2015-01-29  0.907501  0.897501    0.031134  62.123832  6.265084

# %%
from sklearn.preprocessing import MinMaxScaler

# Select features to be included in the model
# features = ['Close', 'width', 'RSI', 'ROC', 'Volume', 'diff', 'pct_change']
features = ['Close']

# Initialize the MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# Scale the selected features
scaled_data = scaler.fit_transform(aapl_data[features])

# Convert the scaled data back to a DataFrame for easier handling
scaled_data_df = pd.DataFrame(scaled_data, columns=features, index=aapl_data.index)

# Display the scaled features
scaled_data_df.head()
# Out:
#                Close
# Date
# 2015-01-23  0.113444
# 2015-01-26  0.114045
# 2015-01-27  0.094203
# 2015-01-28  0.125119
# 2015-01-29  0.143108

# %%
def create_sequences_multifeature(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i + sequence_length])
        y.append(data[i + sequence_length, 0])  # Predicting the next 'Close' price
    return np.array(X), np.array(y)

sequence_length = 60  # Using the last 60 days to predict the next day's price
X, y = create_sequences_multifeature(scaled_data, sequence_length)

# Split data into training and test sets (80% train, 20% test)
split = int(0.7 * len(X))
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:], y[split:]

# Display shapes to confirm
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (827, 60, 1) (827,) (355, 60, 1) (355,)

# %%
def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                            np.arange(d_model)[np.newaxis, :],
                            d_model)
    # Apply sin to even indices and cos to odd indices
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    pos_encoding = angle_rads[np.newaxis, ...]
    return tf.cast(pos_encoding, dtype=tf.float32)

def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    return pos * angle_rates

# Step 7: Define the Transformer Model
from tensorflow.keras.layers import Input, MultiHeadAttention, Dense, LayerNormalization, Dropout
from tensorflow.keras.models import Model
import tensorflow as tf

# %%
from tensorflow.keras.layers import Input, MultiHeadAttention, Dense, LayerNormalization, Dropout
from tensorflow.keras.models import Model
import tensorflow as tf

def transformer_encoder(inputs, num_heads, dff, d_model, dropout_rate):
    attention = MultiHeadAttention(num_heads=num_heads, key_dim=d_model)
    attention_output = attention(inputs, inputs)
    
    # Add & Norm
    attention_output = LayerNormalization(epsilon=1e-6)(attention_output + inputs)
    
    # Feed-forward Network
    ff_output = Dense(dff, activation='relu')(attention_output)
    ff_output = Dense(d_model)(ff_output)
    
    # Add & Norm
    ff_output = LayerNormalization(epsilon=1e-6)(ff_output + attention_output)
    
    return ff_output

# %%
from tensorflow.keras.layers import Dense

# Update the Transformer Model to include a Dense layer to match input features with d_model
def build_transformer_model(sequence_length, num_features, d_model, num_heads, dff, dropout_rate):
    inputs = Input(shape=(sequence_length, num_features))
    
    # Project the input features (num_features) into the same dimension as the positional encoding (d_model)
    input_projection = Dense(d_model)(inputs)
    
    # Positional Encoding
    pos_encoding = positional_encoding(sequence_length, d_model)
    inputs_pos_encoded = input_projection + pos_encoding
    
    # Encoder layers
    encoder_output = transformer_encoder(inputs_pos_encoded, num_heads, dff, d_model, dropout_rate)
    
    # Output layer (regression task)
    outputs = Dense(1)(encoder_output[:, -1, :])  # Use the last time step for prediction
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    
    return model

# Define model parameters
d_model = 128  # Dimension of the model
num_heads = 4  # Number of attention heads
dff = 128  # Feed-forward network dimension
dropout_rate = 0.1  # Dropout rate
num_features = len(features)  # Number of input features (e.g., 7 in this case)

# Build and compile the model
transformer_model = build_transformer_model(sequence_length, num_features, d_model, num_heads, dff, dropout_rate)

# Display the model summary
transformer_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 60, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 60, 128)   │        256 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 60, 128)   │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 60, 128)   │    263,808 │ add[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 60, 128)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 60, 128)   │        256 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 60, 128)   │     16,512 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 60, 128)   │     16,512 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 60, 128)   │          0 │ dense_2[0][0],    │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 60, 128)   │        256 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 128)       │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │        129 │ get_item[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 297,729 (1.14 MB)
#  Trainable params: 297,729 (1.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = transformer_model.fit(X_train, y_train, 
                                validation_data=(X_test, y_test), 
                                epochs=50, 
                                batch_size=64, 
                                callbacks=[early_stop])
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 2.3745 - val_loss: 0.1704
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.1590 - val_loss: 0.2233
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.0467 - val_loss: 0.2301
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.0258 - val_loss: 0.1453
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.0154 - val_loss: 0.1034
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0125 - val_loss: 0.0764
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0117 - val_loss: 0.0559
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0092 - val_loss: 0.0389
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 0.0078 - val_loss: 0.0437
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 0.0055 - val_loss: 0.0416
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 0.0044 - val_loss: 0.0158
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0027 - val_loss: 0.0125
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0016 - val_loss: 0.0091
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0010 - val_loss: 0.0062
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 8.2620e-04 - val_loss: 0.0053
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 7.4514e-04 - val_loss: 0.0048
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 6.3272e-04 - val_loss: 0.0046
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 6.5163e-04 - val_loss: 0.0044
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 6.1389e-04 - val_loss: 0.0041
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 5.9348e-04 - val_loss: 0.0038
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 5.8698e-04 - val_loss: 0.0035
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 5.0676e-04 - val_loss: 0.0034
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 5.6246e-04 - val_loss: 0.0031
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - loss: 5.4290e-04 - val_loss: 0.0030
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 5.1081e-04 - val_loss: 0.0028
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 4.6879e-04 - val_loss: 0.0026
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 4.3936e-04 - val_loss: 0.0025
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 4.0854e-04 - val_loss: 0.0024
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 4.5186e-04 - val_loss: 0.0022
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 4.3557e-04 - val_loss: 0.0020
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 3.6469e-04 - val_loss: 0.0019
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 3.5082e-04 - val_loss: 0.0017
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 3.1970e-04 - val_loss: 0.0016
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 3.6275e-04 - val_loss: 0.0014
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 2.4577e-04 - val_loss: 0.0013
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 2.5235e-04 - val_loss: 0.0011
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 2.4199e-04 - val_loss: 9.7507e-04
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 2.1555e-04 - val_loss: 9.8819e-04
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 2.8957e-04 - val_loss: 9.9451e-04
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 3.3789e-04 - val_loss: 8.0297e-04
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 3.0789e-04 - val_loss: 7.9324e-04
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 2.2827e-04 - val_loss: 7.5810e-04
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 2.9576e-04 - val_loss: 6.9184e-04
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 1.6083e-04 - val_loss: 6.5154e-04
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 1.8414e-04 - val_loss: 6.9146e-04
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 1.8962e-04 - val_loss: 6.8438e-04
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 1.8986e-04 - val_loss: 6.5111e-04
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 1.5043e-04 - val_loss: 5.6065e-04
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 1.8330e-04 - val_loss: 5.5047e-04
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 1.8192e-04 - val_loss: 5.9201e-04

# %%
import matplotlib.pyplot as plt

def plot_loss_curve(history):
    # Extract loss values from the history object
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    # Plotting the loss curves
    plt.figure(figsize=(10, 6))
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss (MSE)')
    plt.legend()
    plt.grid(True)
    plt.show()

# Call the function to plot the loss curve
plot_loss_curve(history)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
# Make predictions on the test data
predictions = transformer_model.predict(X_test)

# Rescale the predictions and actual values back to original scale
predictions_rescaled = scaler.inverse_transform(np.concatenate([predictions, np.zeros((predictions.shape[0], len(features) - 1))], axis=1))[:, 0]
y_test_rescaled = scaler.inverse_transform(np.concatenate([y_test.reshape(-1, 1), np.zeros((y_test.shape[0], len(features) - 1))], axis=1))[:, 0]

# Calculate Mean Squared Error and R² score
mse = mean_squared_error(y_test_rescaled, predictions_rescaled)
r2 = r2_score(y_test_rescaled, predictions_rescaled)
mape = mean_absolute_percentage_error(y_test_rescaled, predictions_rescaled)
print(f'Mean Squared Error: {mse}')
print(f'R² Score: {r2}')
print(f'MAPE Score: {mape}')

# Plot the results
plt.figure(figsize=(10,6))
plt.plot(aapl_data.index[split+sequence_length:], y_test_rescaled, label='Actual Price')
plt.plot(aapl_data.index[split+sequence_length:], predictions_rescaled, label='Predicted Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.title('AAPL Stock Price Prediction Using Transformer with Multiple Features')
plt.legend()
plt.show()
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Mean Squared Error: 1.3702547837283114
# R² Score: 0.9772464330361114
# MAPE Score: 0.017485309160181386

# %%
# Save the model weights manually after training
transformer_model.save_weights('try_final_transformer_model1.weights.h5')
