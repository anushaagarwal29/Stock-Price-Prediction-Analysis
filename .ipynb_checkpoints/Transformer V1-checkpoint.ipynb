# %%
# Install necessary packages
# !pip install yfinance tensorflow numpy pandas matplotlib scikit-learn

import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LayerNormalization, Dropout
from tensorflow.keras.layers import MultiHeadAttention, Embedding
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, r2_score

# Step 1: Load AAPL stock data from 2015 to 2019
aapl_data = yf.download('AAPL', start='2015-01-01', end='2019-12-30', interval='1d')

# Step 2: Preprocess the data
# Use the 'Adj Close' price for the prediction task
aapl_data = aapl_data[['Adj Close']]

# Fill missing values
aapl_data.fillna(method='ffill', inplace=True)

# Step 3: Scaling the data using MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(aapl_data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /var/folders/sf/wjf5n1r162zfj7_jsjdk2dkm0000gn/T/ipykernel_2707/55238538.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aapl_data.fillna(method='ffill', inplace=True)

# %%
# Step 4: Create sequences for Transformer input
def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i + sequence_length])
        y.append(data[i + sequence_length])
    return np.array(X), np.array(y)

sequence_length = 60  # We will use the last 60 days to predict the next day's stock price
X, y = create_sequences(scaled_data, sequence_length)

# Step 5: Split the data into training and test sets
split = int(0.8 * len(X))
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:], y[split:]

# Step 6: Positional Encoding Function for Time-Series Data
def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                            np.arange(d_model)[np.newaxis, :],
                            d_model)
    # Apply sin to even indices and cos to odd indices
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    pos_encoding = angle_rads[np.newaxis, ...]
    return tf.cast(pos_encoding, dtype=tf.float32)

def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    return pos * angle_rates

# %%
# Step 7: Define the Transformer Model
from tensorflow.keras.layers import Input, MultiHeadAttention, Dense, LayerNormalization, Dropout
from tensorflow.keras.models import Model
import tensorflow as tf

def transformer_encoder(inputs, num_heads, dff, d_model, dropout_rate):
    attention = MultiHeadAttention(num_heads=num_heads, key_dim=d_model)
    attention_output = attention(inputs, inputs)
    
    # Add & Norm
    attention_output = LayerNormalization(epsilon=1e-6)(attention_output + inputs)
    
    # Feed-forward Network
    ff_output = Dense(dff, activation='relu')(attention_output)
    ff_output = Dense(d_model)(ff_output)
    
    # Add & Norm
    ff_output = LayerNormalization(epsilon=1e-6)(ff_output + attention_output)
    
    return ff_output

def build_transformer_model(sequence_length, d_model, num_heads, dff, num_layers, dropout_rate):
    inputs = Input(shape=(sequence_length, 1))
    
    # Positional Encoding
    pos_encoding = positional_encoding(sequence_length, d_model)
    inputs_pos_encoded = inputs + pos_encoding
    
    # Encoder layers
    encoder_output = transformer_encoder(inputs_pos_encoded, num_heads, dff, d_model, dropout_rate)
    
    # Output layer (regression task)
    outputs = Dense(1)(encoder_output[:, -1, :])  # Use the last time step for prediction
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Step 8: Build the model with specified parameters
d_model = 64  # Dimension of the model
num_heads = 4  # Number of attention heads
num_layers = 2
dff = 128  # Feed-forward network dimension
dropout_rate = 0.1  # Dropout rate

transformer_model = build_transformer_model(sequence_length, d_model, num_heads, dff, num_layers, dropout_rate)

# %%
# Step 9: Train the model
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
history = transformer_model.fit(X_train, y_train, 
                                validation_data=(X_test, y_test), 
                                epochs=100, 
                                batch_size=32, 
                                callbacks=[early_stop])
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0364e-04 - val_loss: 0.0031
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.3200e-04 - val_loss: 0.0039
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1055e-04 - val_loss: 0.0044
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7377e-04 - val_loss: 0.0024
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4797e-04 - val_loss: 0.0026
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8173e-04 - val_loss: 0.0023
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.8454e-04 - val_loss: 0.0026
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.8854e-04 - val_loss: 0.0032
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.8635e-04 - val_loss: 0.0024
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.9584e-04 - val_loss: 0.0029
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9986e-04 - val_loss: 0.0032
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9856e-04 - val_loss: 0.0023
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1453e-04 - val_loss: 0.0031
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9321e-04 - val_loss: 0.0030
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8470e-04 - val_loss: 0.0028
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8327e-04 - val_loss: 0.0027
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0439e-04 - val_loss: 0.0023
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8428e-04 - val_loss: 0.0023
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0629e-04 - val_loss: 0.0023
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8549e-04 - val_loss: 0.0026
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5441e-04 - val_loss: 0.0023
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7877e-04 - val_loss: 0.0019
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6558e-04 - val_loss: 0.0023
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4714e-04 - val_loss: 0.0027
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.9658e-04 - val_loss: 0.0023
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5876e-04 - val_loss: 0.0019
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.8313e-04 - val_loss: 0.0031
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3540e-04 - val_loss: 0.0018
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.6126e-04 - val_loss: 0.0028
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3619e-04 - val_loss: 0.0032
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.5196e-04 - val_loss: 0.0021
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1718e-04 - val_loss: 0.0021
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.6793e-04 - val_loss: 0.0021
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.7254e-04 - val_loss: 0.0028
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6891e-04 - val_loss: 0.0019
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6469e-04 - val_loss: 0.0028
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6382e-04 - val_loss: 0.0029
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9651e-04 - val_loss: 0.0024
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6503e-04 - val_loss: 0.0030
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1547e-04 - val_loss: 0.0019
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6697e-04 - val_loss: 0.0031
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9506e-04 - val_loss: 0.0024
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8989e-04 - val_loss: 0.0022
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6273e-04 - val_loss: 0.0026
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5011e-04 - val_loss: 0.0039
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.4500e-04 - val_loss: 0.0022
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7322e-04 - val_loss: 0.0021
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5864e-04 - val_loss: 0.0019

# %%
# Step 10: Make predictions on the test data
predictions = transformer_model.predict(X_test)

# Rescale predictions and actual values back to original scale
predictions_rescaled = scaler.inverse_transform(predictions)
y_test_rescaled = scaler.inverse_transform(y_test)

# Step 11: Evaluate the model
mse = mean_squared_error(y_test_rescaled, predictions_rescaled)
r2 = r2_score(y_test_rescaled, predictions_rescaled)
print(f'Mean Squared Error: {mse}')
print(f'R² Score: {r2}')

# Step 12: Visualize the predictions
plt.figure(figsize=(10,6))
plt.plot(aapl_data.index[split+sequence_length:], y_test_rescaled, label='Actual Price')
plt.plot(aapl_data.index[split+sequence_length:], predictions_rescaled, label='Predicted Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.title('AAPL Stock Price Prediction Using Transformer')
plt.legend()
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Mean Squared Error: 4.3919772414770115
# R² Score: 0.9314916244131047
